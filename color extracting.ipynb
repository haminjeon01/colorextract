# %%
pip install opencv-python
# Out:
# ...
#
# ...
#      ---------------------------------------- 38.2/38.2 MB 8.6 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import cv2
import matplotlib.image as mpimg
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans

# %matplotlib inline

# %%
def centroid_histogram(clt):
    # grab the number of different clusters and create a histogram
    # based on the number of pixels assigned to each cluster
    numLabels = np.arange(0, len(np.unique(clt.labels_)) + 1)
    (hist, _) = np.histogram(clt.labels_, bins=numLabels)

    # normalize the histogram, such that it sums to one
    hist = hist.astype("float")
    hist /= hist.sum()

    # return the histogram
    return hist

def plot_colors(hist, centroids):
    # initialize the bar chart representing the relative frequency
    # of each of the colors
    bar = np.zeros((50, 300, 3), dtype="uint16")
    startX = 0

    # loop over the percentage of each cluster and the color of
    # each cluster
    for (percent, color) in zip(hist, centroids):
        # plot the relative percentage of each cluster
        endX = startX + (percent * 300)
        cv2.rectangle(bar, (int(startX), 0), (int(endX), 50),
                      color.astype("uint16").tolist(), -1)
        startX = endX

    # return the bar chart
    return bar

# %%
def image_color_cluster(image_path, k = 5):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = image.reshape((image.shape[0] * image.shape[1], 3))
    
    clt = KMeans(n_clusters = k)
    clt.fit(image)

    hist = centroid_histogram(clt)
    bar = plot_colors(hist, clt.cluster_centers_)
    
    plt.figure()
    plt.axis("off")
    plt.imshow(bar)
    plt.show()

# %%
image_path = 'C:/Users/user/Desktop/color/depressed.jpg'
#preview image
image = mpimg.imread(image_path)
plt.imshow(image)

image_color_cluster(image_path)

# %%
import os, sys
from PIL import Image
im=Image.open('C:/Users/User/Desktop/color/depressed_bar.jpg')
plt.imshow(im)
rgb_im=im.convert('RGB')
r,g,b=rgb_im.getpixel((1200,100))

print(im.size)
print(r,g,b)
# Out:
# (1350, 211)
# 134 190 213

# %%
c=np.arange(1,1350,1)
text=open('C:/Users/User/Desktop/color/depressed_bar.txt','a')
for a in c:
    print(rgb_im.getpixel((a,100)), file=text)
text.close()

# %%
import pandas as pd
data=pd.read_csv('C:/Users/User/Desktop/color/depressed_bar.csv')

# %%
import matplotlib.ticker as ticker
plt.figure(figsize=(15,2))
plt.plot(data['R'],c='r',label='R')
plt.plot(data['G'],c='g',label='G')
plt.plot(data['B'],c='b',label='B')
plt.legend()
plt.xlim(0,1350)
plt.ylim(0,256)
plt.savefig('C:/Users/User/Desktop/color/depressed_bar.png')
plt.show()
im=Image.open('C:/Users/User/Desktop/color/depressed_bar.jpg')
plt.figure(figsize=(15,2))
plt.imshow(im)

# %%
images = [
    'C:/Users/user/Desktop/color/depressed_2.jpg',
    'C:/Users/user/Desktop/color/depressed_3.jpg',
    'C:/Users/user/Desktop/color/depressed_4.jpg',
    'C:/Users/user/Desktop/color/depressed_5.jpg',
    'C:/Users/user/Desktop/color/depressed_6.jpg',
    'C:/Users/user/Desktop/color/depressed_7.jpg',
    'C:/Users/user/Desktop/color/depressed_8.jpg',
    'C:/Users/user/Desktop/color/depressed_9.jpg',
    'C:/Users/user/Desktop/color/depressed_10.jpg',
]


for image_path in images:
    image = mpimg.imread(image_path)
    plt.imshow(image)

    image_color_cluster(image_path)

# %%
import os, sys
from PIL import Image
im=Image.open('C:/Users/User/Desktop/color/depressed_bar2.jpg')
plt.imshow(im)
rgb_im=im.convert('RGB')
r,g,b=rgb_im.getpixel((1300,100))

print(im.size)
print(r,g,b)
# Out:
# (1350, 211)
# 21 37 50

# %%
import os, sys
from PIL import Image
im=Image.open('C:/Users/User/Desktop/color/depressed_bar3.jpg')
plt.imshow(im)
rgb_im=im.convert('RGB')
r,g,b=rgb_im.getpixel((1300,100))

print(im.size)
print(r,g,b)
# Out:
# (1350, 211)
# 54 54 80

# %%
import os, sys
from PIL import Image
im=Image.open('C:/Users/User/Desktop/color/depressed_bar4.jpg')
plt.imshow(im)
rgb_im=im.convert('RGB')
r,g,b=rgb_im.getpixel((1300,100))

print(im.size)
print(r,g,b)
# Out:
# (1350, 211)
# 86 108 122

# %%
import os, sys
from PIL import Image
im=Image.open('C:/Users/User/Desktop/color/depressed_bar5.jpg')
plt.imshow(im)
rgb_im=im.convert('RGB')
r,g,b=rgb_im.getpixel((1300,100))

print(im.size)
print(r,g,b)
# Out:
# (1350, 211)
# 129 155 192

# %%
import os, sys
from PIL import Image
im=Image.open('C:/Users/User/Desktop/color/depressed_bar6.jpg')
plt.imshow(im)
rgb_im=im.convert('RGB')
r,g,b=rgb_im.getpixel((1300,100))

print(im.size)
print(r,g,b)
# Out:
# (1350, 212)
# 86 119 154

# %%
import os, sys
from PIL import Image
im=Image.open('C:/Users/User/Desktop/color/depressed_bar7.jpg')
plt.imshow(im)
rgb_im=im.convert('RGB')
r,g,b=rgb_im.getpixel((1200,100))

print(im.size)
print(r,g,b)
# Out:
# (1350, 211)
# 42 58 109

# %%
import os, sys
from PIL import Image
im=Image.open('C:/Users/User/Desktop/color/depressed_bar8.jpg')
plt.imshow(im)
rgb_im=im.convert('RGB')
r,g,b=rgb_im.getpixel((1300,100))

print(im.size)
print(r,g,b)
# Out:
# (1350, 212)
# 171 187 177

# %%
import os, sys
from PIL import Image
im=Image.open('C:/Users/User/Desktop/color/depressed_bar9.jpg')
plt.imshow(im)
rgb_im=im.convert('RGB')
r,g,b=rgb_im.getpixel((1200,100))

print(im.size)
print(r,g,b)
# Out:
# (1350, 211)
# 83 120 139

# %%
import os, sys
from PIL import Image
im=Image.open('C:/Users/User/Desktop/color/depressed_bar10.jpg')
plt.imshow(im)
rgb_im=im.convert('RGB')
r,g,b=rgb_im.getpixel((1200,100))

print(im.size)
print(r,g,b)
# Out:
# (1350, 211)
# 47 100 170

# %%
#data 3d
import matplotlib.pyplot as plt
import numpy as np

fig=plt.figure()
ax=fig.gca(projection='3d')

data=np.loadtxt('C:/Users/User/Desktop/color/depressed_bars.csv',unpack=True, delimiter=',',skiprows=1)
X=data[0]
Y=data[1]
Z=data[2]

ax.scatter(X,Y,Z)

ax.set_xlabel('R')
ax.set_ylabel('G')
ax.set_zlabel('B')
plt.suptitle('RGB of 10 pics', fontsize=16)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_40592\4123113255.py:6: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax=fig.gca(projection='3d')

# %%
#clustering
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
import numpy as np
import random as rd

# %%
# rgb of 10 pics csv
df = pd.read_csv('C:/Users/User/Desktop/color/depressed_bars.csv', encoding='cp949')
df.head()
# Out:
#      R    G    B
# 0   24   58   68
# 1   86  145  175
# 2   12   17   20
# 3   58  107  137
# 4  134  190  213

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   R       50 non-null     int64
#  1   G       50 non-null     int64
#  2   B       50 non-null     int64
# dtypes: int64(3)
# memory usage: 1.3 KB

# %%
df.describe()
# Out:
#                 R           G           B
# count   50.000000   50.000000   50.000000
# mean    75.700000  106.000000  135.160000
# std     56.837847   62.411407   68.030713
# min      3.000000    5.000000   12.000000
# 25%     27.250000   58.000000   80.000000
# 50%     55.000000  101.500000  138.000000
# 75%    127.000000  150.750000  190.000000
# max    196.000000  218.000000  254.000000

# %%
df_f=df.copy()

# %%
# 3차원 그리기

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

X = df_f

# 3d scatterplot 그리기
ax.scatter(  X.iloc[:,0]
           , X.iloc[:,1]
           , X.iloc[:,2]
#           , c=X.index #마커컬러
           , s=10 #사이즈
           , cmap="orange" #컬러맵
           , alpha=1 #투명도
           , label='class1' #범례
          )

plt.legend() #범례표시
plt.show()

# %%
from sklearn.cluster import KMeans
# 적절한 군집수 찾기
# Inertia(군집 내 거리제곱합의 합) value (적정 군집수)

ks = range(1,10)
inertias = []

for k in ks:
    model = KMeans(n_clusters=k)
    model.fit(df_f)
    inertias.append(model.inertia_)

# Plot ks vs inertias
plt.figure(figsize=(4, 4))

plt.plot(ks, inertias, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()
# Out:
# C:\Users\user\.jupyter\dd\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# K-Means 모델과 군집 예측값을 생성

# 클러스터 모델 생성 파라미터는 원할 경우 추가
clust_model = KMeans(n_clusters = 3 # 클러스터 갯수
#                      , n_init=10 # initial centroid를 몇번 샘플링한건지, 데이터가 많으면 많이 돌릴수록안정화된 결과가 나옴
#                      , max_iter=500 # KMeans를 몇번 반복 수행할건지, K가 큰 경우 1000정도로 높여준다
#                      , random_state = 42
#                      , algorithm='auto'
                    )

# 생성한 모델로 데이터를 학습시킴
clust_model.fit(df_f) # unsupervised learning 

# 결과 값을 변수에 저장
centers = clust_model.cluster_centers_ # 각 군집의 중심점
pred = clust_model.predict(df_f) # 각 예측군집

print(pd.DataFrame(centers))
print(pred[:10])
# Out:
#             0           1           2
# 0   58.421053  100.105263  141.894737
# 1  146.125000  179.062500  205.500000
# 2   22.466667   35.533333   51.600000
# [2 0 2 0 1 0 1 0 1 2]

# %%
# 원래 데이터에 예측된 군집 붙이기
clust_df = df_f.copy()
clust_df['clust'] = pred
clust_df.head()
# Out:
#      R    G    B  clust
# 0   24   58   68      2
# 1   86  145  175      0
# 2   12   17   20      2
# 3   58  107  137      0
# 4  134  190  213      1

# %%
# 3차원으로 시각화하기

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

X = clust_df

# 데이터 scatterplot
ax.scatter(  X.iloc[:,0]
           , X.iloc[:,1]
           , X.iloc[:,2]
           , c = X.clust
           , s = 10
           , cmap = "rainbow"
           , alpha = 1
          )

# centroid scatterplot
ax.scatter(centers[:,0],centers[:,1],centers[:,2] ,c='black', s=200, marker='*')
ax.set_xlabel('R')
ax.set_ylabel('G')
ax.set_zlabel('B')

plt.show()

# %%
cluster_mean= clust_df.groupby('clust').mean()
cluster_mean
# Out:
#                 R           G           B
# clust
# 0       58.421053  100.105263  141.894737
# 1      146.125000  179.062500  205.500000
# 2       22.466667   35.533333   51.600000

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

palette = [(58,100,142),(146,179,206),(22,36,52)]

palette = np.array(palette)[np.newaxis, :, :]

plt.imshow(palette)
plt.axis('off')
plt.show()

# %%
import numpy as np
from PIL import Image

data=np.zeros([32,32,3],dtype=np.uint8)
image=Image.fromarray(data,'RGB')
image
# Out:
# <PIL.Image.Image image mode=RGB size=32x32>
